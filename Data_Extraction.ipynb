# %% [raw]
# The midterm presentations will be in mid-October.
# You need choose a dataset by then, decide what supervised ML task you want to solve, perform EDA, split and preprocess your dataset.
# The midterm presentation rubric will be released during the second half of September.

# %% [raw]
# Show us what you think were the most interesting, unexpected, or important insights that you gained during EDA.
# Present at least three different informative visualization types.
# Do not create only three figures.
# Create as many figures you can to better understand your dataset and calculate summary statistics as well.
# Then select three figures that you want to show during the presentation.
# Explain why you chose the figures! Why are they interesting, unexpected, important?

# %% [raw]
# Describe briefly how you split the data and why.
# What preprocessors did you use, and why?
# How many features and data points do you have before and after preprocessing.
# If you have missing values, describe the basic properties of the missing values
# (e.g., what fraction of the points have missing values, which features, what fraction of the features are missing, etc).

# %% [markdown]
# # Outcomes data

# %%
import pandas as pd
import numpy as np

outcomes_df = pd.read_csv("aac_outcomes.csv")
outcomes_df.drop(['date_of_birth','monthyear','outcome_subtype'], axis = 1, inplace = True)
outcomes_df = outcomes_df[outcomes_df['animal_type'].isin(['Cat', 'Dog'])]
# Reset index after filtering
outcomes_df = outcomes_df.reset_index(drop=True)

# print(outcomes_df)
print(outcomes_df.shape)
# Out:
# (163904, 9)

# %%
outcomes_df.columns # We will drop animal_id later + maybe datetime as well as it leaks data + sex_upon_outcome and age_upon_outcome as well since that datais not available at the intake where the shelter wants to predict
# Out:
# Index(['animal_id', 'name', 'outcome_type', 'animal_type', 'sex_upon_outcome',
#        'age_upon_outcome', 'breed', 'color', 'datetime'],
#       dtype='object')

# %%
outcomes_df.isnull().sum()
# Out:
# animal_id               0
# name                41759
# outcome_type           39
# animal_type             0
# sex_upon_outcome        1
# age_upon_outcome        5
# breed                   0
# color                   0
# datetime                0
# dtype: int64

# %%
# outcomes_df['animal_id'].value_counts() # We will keep the latest outcome one

# %%
# outcomes_df['name'].nunique()

# %%
# outcomes_df['outcome_type'].value_counts()

# %%
# outcomes_df['animal_type'].value_counts()

# %%
# outcomes_df['sex_upon_outcome'].value_counts()

# %%
# outcomes_df['age_upon_outcome'].value_counts()

# %%
# outcomes_df['breed'].nunique()

# %%
# outcomes_df['color'].nunique()

# %%
# outcomes_df['datetime'] # We need to conver this to datetime object and the format should be consistent accross the data
# Out:
# 0         2015-07-02T00:00:00-05:00
# 1         2016-06-20T00:00:00-05:00
# 2         2015-11-11T00:00:00-05:00
# 3         2015-06-30T00:00:00-05:00
# 4         2015-11-17T00:00:00-05:00
#                     ...
# 163899          2025-05-04T12:48:00
# 163900          2025-05-01T16:54:00
# 163901          2025-05-04T17:53:00
# 163902          2025-05-04T14:18:00
# 163903          2025-05-05T00:00:00
# Name: datetime, Length: 163904, dtype: object

# %%
import pandas as pd
import dateutil

def parse_any_datetime(val, default_tz="UTC"):
    try:
        dt = pd.to_datetime(val, utc=True)   # works for both offset and normal
        return dt
    except Exception:
        # Fallback: parse with dateutil and assign default timezone
        dt = dateutil.parser.parse(val)
        return dt.tz_localize(default_tz).tz_convert("UTC")

outcomes_df['datetime'] = outcomes_df['datetime'].astype(str).apply(parse_any_datetime)
outcomes_df['datetime'] = outcomes_df['datetime'].dt.tz_localize(None)

# %%
# outcomes_df['animal_id'].value_counts()

# %%
# outcomes_df[outcomes_df['animal_id'] == 'A721033']

# %%
# Step 1: Count number of visits per animal_id
visit_counts = outcomes_df['animal_id'].value_counts()

# Step 2: Keep only the latest record per animal_id
outcomes_latest = outcomes_df.sort_values(['animal_id', 'datetime']).groupby('animal_id').tail(1)

# Step 3: Add visit_count column
outcomes_latest['visit_count'] = outcomes_latest['animal_id'].map(visit_counts)

# Step 4: Reset index for neatness
outcomes_latest = outcomes_latest.reset_index(drop=True)

# %%
outcomes_latest[outcomes_latest['animal_id'] == 'A721033']
# Out:
#       animal_id     name outcome_type animal_type sex_upon_outcome  \
# 40454   A721033  Lil Bit    Rto-Adopt         Dog    Neutered Male
#
#       age_upon_outcome            breed                   color  \
# 40454          4 years  Rat Terrier Mix  Tricolor/Brown Brindle
#
#                  datetime  visit_count
# 40454 2019-10-20 11:35:00           33

# %%
outcomes_latest['animal_id'].value_counts()
# Out:
# animal_id
# A929710    1
# A006100    1
# A047759    1
# A134067    1
# A141142    1
#           ..
# A212672    1
# A210457    1
# A208755    1
# A200922    1
# A197810    1
# Name: count, Length: 146409, dtype: int64

# %%
outcomes_latest['datetime']
# Out:
# 0        2017-12-07 05:00:00
# 1        2014-04-07 15:12:00
# 2        2013-11-16 11:54:00
# 3        2013-11-17 11:40:00
# 4        2014-11-14 19:28:00
#                  ...
# 146404   2025-05-02 18:44:00
# 146405   2025-05-02 18:43:00
# 146406   2025-05-03 13:19:00
# 146407   2025-05-03 11:27:00
# 146408   2025-05-04 17:13:03
# Name: datetime, Length: 146409, dtype: datetime64[ns]

# %%
outcomes_latest.columns
# Out:
# Index(['animal_id', 'name', 'outcome_type', 'animal_type', 'sex_upon_outcome',
#        'age_upon_outcome', 'breed', 'color', 'datetime', 'visit_count'],
#       dtype='object')

# %%
outcomes_latest
# Out:
#        animal_id    name     outcome_type animal_type sex_upon_outcome  \
# 0        A006100   Scamp  Return to Owner         Dog    Neutered Male
# 1        A047759    Oreo         Transfer         Dog    Neutered Male
# 2        A134067  Bandit  Return to Owner         Dog    Neutered Male
# 3        A141142  Bettie  Return to Owner         Dog    Spayed Female
# 4        A163459   Sasha  Return to Owner         Dog    Intact Female
# ...          ...     ...              ...         ...              ...
# 146404   A929599     NaN         Transfer         Cat          Unknown
# 146405   A929600     NaN         Transfer         Cat          Unknown
# 146406   A929602     NaN         Transfer         Cat          Unknown
# 146407   A929631   Fiona       Euthanasia         Dog    Spayed Female
# 146408   A929710     NaN       Euthanasia         Cat    Neutered Male
#
#        age_upon_outcome                          breed         color  \
# 0              10 years           Spinone Italiano Mix  Yellow/White
# 1              10 years                      Dachshund      Tricolor
# 2              16 years              Shetland Sheepdog   Brown/White
# 3              15 years    Labrador Retriever/Pit Bull   Black/White
# 4              15 years        Miniature Schnauzer Mix    Black/Gray
# ...                 ...                            ...           ...
# 146404           4 days             Domestic Shorthair   Brown Tabby
# 146405           4 days             Domestic Shorthair   Brown Tabby
# 146406           1 year             Domestic Shorthair         Black
# 146407         16 years  Chihuahua Shorthair/Dachshund           Tan
# 146408              NaN             American Shorthair   White/Black
#
#                   datetime  visit_count
# 0      2017-12-07 05:00:00            3
# 1      2014-04-07 15:12:00            1
# 2      2013-11-16 11:54:00            1
# 3      2013-11-17 11:40:00            1
# 4      2014-11-14 19:28:00            1
# ...                    ...          ...
# 146404 2025-05-02 18:44:00            1
# 146405 2025-05-02 18:43:00            1
# 146406 2025-05-03 13:19:00            1
# 146407 2025-05-03 11:27:00            1
# 146408 2025-05-04 17:13:03            1
#
# [146409 rows x 10 columns]

# %% [markdown]
# # Intakes data

# %%
import pandas as pd
import numpy as np
intakes_df = pd.read_csv("aac_intakes.csv")

# %%
intakes_df.drop(['datetime2','found_location'], axis = 1, inplace = True)
intakes_df = intakes_df[intakes_df['animal_type'].isin(['Cat', 'Dog'])]
# Reset index after filtering
intakes_df = intakes_df.reset_index(drop=True)

print(intakes_df)
print(intakes_df.shape)
print(intakes_df.columns)
# Out:
#                        datetime animal_id     name      intake_type  \
# 0       2013-10-01T16:10:00.000   A664308    Bruce            Stray
# 1       2013-10-11T18:13:00.000   A664968    Simba            Stray
# 2       2013-10-14T11:23:00.000   A665140      NaN            Stray
# 3       2013-10-01T15:58:00.000   A659642  *Trevor  Owner Surrender
# 4       2013-10-04T11:05:00.000   A664489   Nikole            Stray
# ...                         ...       ...      ...              ...
# 163927  2025-04-18T08:44:00.000   A928711      Red            Stray
# 163928  2025-04-29T14:05:00.000   A929392      NaN            Stray
# 163929  2025-04-15T14:13:00.000   A928558  *Murphy            Stray
# 163930  2025-05-02T22:01:00.000   A929633      NaN            Stray
# 163931  2025-04-23T16:53:00.000   A926662   Pancho    Public Assist
#
#        intake_condition animal_type sex_upon_intake age_upon_intake  \
# 0                Normal         Dog     Intact Male         6 years
# 1                Normal         Dog     Intact Male       11 months
# 2                Normal         Cat     Intact Male         2 weeks
# 3                Normal         Dog   Neutered Male         2 years
# 4                Normal         Dog   Intact Female         1 month
# ...                 ...         ...             ...             ...
# 163927         Neonatal         Cat         Unknown           1 day
# 163928           Normal         Cat   Intact Female           1 day
# 163929           Normal         Cat     Intact Male          1 year
# 163930           Normal         Dog   Intact Female        7 months
# 163931           Normal         Dog     Intact Male         4 years
#
#                             breed          color
# 0       Australian Cattle Dog Mix       Tricolor
# 1             German Shepherd Mix      Tan/Black
# 2          Domestic Shorthair Mix    Black/White
# 3          Dachshund/Basset Hound  Brown Brindle
# 4          Labrador Retriever Mix    Black/White
# ...                           ...            ...
# 163927         Domestic Shorthair   White/Orange
# 163928         Domestic Shorthair   Torbie/White
# 163929         Domestic Shorthair           Blue
# 163930               Pit Bull Mix  Black Brindle
# 163931            German Shepherd          Black
#
# [163932 rows x 10 columns]
# (163932, 10)
# Index(['datetime', 'animal_id', 'name', 'intake_type', 'intake_condition',
#        'animal_type', 'sex_upon_intake', 'age_upon_intake', 'breed', 'color'],
#       dtype='object')

# %%
# intakes_df['animal_id'].value_counts()

# %%
intakes_df['datetime'] = intakes_df['datetime'].astype(str).apply(parse_any_datetime)
intakes_df['datetime'] = intakes_df['datetime'].dt.tz_localize(None)

# %%
# intakes_df[intakes_df['animal_id'] == 'A721033']

# %%
# Keep only the latest outcome for each animal_id
intakes_df = intakes_df.sort_values('datetime')  # sort by datetime
intakes_df = intakes_df.groupby('animal_id').tail(1)  # keep last row per animal_id

# Reset index for neatness
intakes_latest = intakes_df.reset_index(drop=True)

print(intakes_latest.shape)
print(intakes_latest.head())
# Out:
# (146450, 10)
#              datetime animal_id    name intake_type intake_condition  \
# 0 2013-10-01 07:51:00   A521520    Nina       Stray           Normal
# 1 2013-10-01 08:33:00   A664237     NaN       Stray           Normal
# 2 2013-10-01 08:33:00   A664236     NaN       Stray           Normal
# 3 2013-10-01 08:33:00   A664235     NaN       Stray           Normal
# 4 2013-10-01 08:53:00   A664233  Stevie       Stray          Injured
#
#   animal_type sex_upon_intake age_upon_intake                         breed  \
# 0         Dog   Spayed Female         7 years  Border Terrier/Border Collie
# 1         Cat         Unknown          1 week        Domestic Shorthair Mix
# 2         Cat         Unknown          1 week        Domestic Shorthair Mix
# 3         Cat         Unknown          1 week        Domestic Shorthair Mix
# 4         Dog   Intact Female         3 years                  Pit Bull Mix
#
#           color
# 0     White/Tan
# 1  Orange/White
# 2  Orange/White
# 3  Orange/White
# 4    Blue/White

# %%
intakes_latest[intakes_latest['animal_id'] == 'A721033']
# Out:
#                  datetime animal_id     name    intake_type intake_condition  \
# 90312 2019-10-05 12:31:00   A721033  Lil Bit  Public Assist           Normal
#
#       animal_type sex_upon_intake age_upon_intake            breed  \
# 90312         Dog   Neutered Male         4 years  Rat Terrier Mix
#
#                         color
# 90312  Tricolor/Brown Brindle

# %%
# intakes_latest['animal_id'].value_counts()
# Out:
# animal_id
# A929635    1
# A521520    1
# A929699    1
# A929697    1
# A929690    1
#           ..
# A664234    1
# A664238    1
# A664233    1
# A664235    1
# A664236    1
# Name: count, Length: 146450, dtype: int64

# %%
# intakes_latest['datetime']
# Out:
# 0        2013-10-01 07:51:00
# 1        2013-10-01 08:33:00
# 2        2013-10-01 08:33:00
# 3        2013-10-01 08:33:00
# 4        2013-10-01 08:53:00
#                  ...
# 146445   2025-05-04 12:43:00
# 146446   2025-05-04 13:15:00
# 146447   2025-05-04 15:14:00
# 146448   2025-05-04 22:55:00
# 146449   2025-05-04 23:44:00
# Name: datetime, Length: 146450, dtype: datetime64[ns]

# %%
outcomes_latest.columns
# Out:
# Index(['animal_id', 'name', 'outcome_type', 'animal_type', 'sex_upon_outcome',
#        'age_upon_outcome', 'breed', 'color', 'datetime', 'visit_count'],
#       dtype='object')

# %%
intakes_latest.columns
# Out:
# Index(['datetime', 'animal_id', 'name', 'intake_type', 'intake_condition',
#        'animal_type', 'sex_upon_intake', 'age_upon_intake', 'breed', 'color'],
#       dtype='object')

# %% [markdown]
# # Merge outcomes and intakes:

# %%
merged_df = pd.merge(
    outcomes_latest,
    intakes_latest,
    on="animal_id",
    how="inner",
    suffixes=("_outcome", "_intake")
)

# %%
print(merged_df)
# Out:
#        animal_id name_outcome     outcome_type animal_type_outcome  \
# 0        A006100        Scamp  Return to Owner                 Dog
# 1        A047759         Oreo         Transfer                 Dog
# 2        A134067       Bandit  Return to Owner                 Dog
# 3        A141142       Bettie  Return to Owner                 Dog
# 4        A163459        Sasha  Return to Owner                 Dog
# ...          ...          ...              ...                 ...
# 145598   A929599          NaN         Transfer                 Cat
# 145599   A929600          NaN         Transfer                 Cat
# 145600   A929602          NaN         Transfer                 Cat
# 145601   A929631        Fiona       Euthanasia                 Dog
# 145602   A929710          NaN       Euthanasia                 Cat
#
#        sex_upon_outcome age_upon_outcome                  breed_outcome  \
# 0         Neutered Male         10 years           Spinone Italiano Mix
# 1         Neutered Male         10 years                      Dachshund
# 2         Neutered Male         16 years              Shetland Sheepdog
# 3         Spayed Female         15 years    Labrador Retriever/Pit Bull
# 4         Intact Female         15 years        Miniature Schnauzer Mix
# ...                 ...              ...                            ...
# 145598          Unknown           4 days             Domestic Shorthair
# 145599          Unknown           4 days             Domestic Shorthair
# 145600          Unknown           1 year             Domestic Shorthair
# 145601    Spayed Female         16 years  Chihuahua Shorthair/Dachshund
# 145602    Neutered Male              NaN             American Shorthair
#
#        color_outcome    datetime_outcome  visit_count     datetime_intake  \
# 0       Yellow/White 2017-12-07 05:00:00            3 2017-12-07 14:07:00
# 1           Tricolor 2014-04-07 15:12:00            1 2014-04-02 15:55:00
# 2        Brown/White 2013-11-16 11:54:00            1 2013-11-16 09:02:00
# 3        Black/White 2013-11-17 11:40:00            1 2013-11-16 14:46:00
# 4         Black/Gray 2014-11-14 19:28:00            1 2014-11-14 15:11:00
# ...              ...                 ...          ...                 ...
# 145598   Brown Tabby 2025-05-02 18:44:00            1 2025-05-02 12:22:00
# 145599   Brown Tabby 2025-05-02 18:43:00            1 2025-05-02 12:22:00
# 145600         Black 2025-05-03 13:19:00            1 2025-05-02 12:22:00
# 145601           Tan 2025-05-03 11:27:00            1 2025-05-02 20:27:00
# 145602   White/Black 2025-05-04 17:13:03            1 2025-05-04 13:15:00
#
#        name_intake      intake_type intake_condition animal_type_intake  \
# 0            Scamp            Stray           Normal                Dog
# 1             Oreo  Owner Surrender           Normal                Dog
# 2           Bandit    Public Assist          Injured                Dog
# 3           Bettie            Stray             Aged                Dog
# 4            Sasha            Stray           Normal                Dog
# ...            ...              ...              ...                ...
# 145598         NaN            Stray         Neonatal                Cat
# 145599         NaN            Stray         Neonatal                Cat
# 145600         NaN            Stray           Normal                Cat
# 145601       Fiona            Stray          Injured                Dog
# 145602         NaN            Stray             Sick                Cat
#
#        sex_upon_intake age_upon_intake                   breed_intake  \
# 0        Neutered Male        10 years           Spinone Italiano Mix
# 1        Neutered Male        10 years                      Dachshund
# 2        Neutered Male        16 years              Shetland Sheepdog
# 3        Spayed Female        15 years    Labrador Retriever/Pit Bull
# 4        Intact Female        15 years        Miniature Schnauzer Mix
# ...                ...             ...                            ...
# 145598         Unknown          4 days             Domestic Shorthair
# 145599         Unknown          4 days             Domestic Shorthair
# 145600         Unknown          1 year             Domestic Shorthair
# 145601   Spayed Female        16 years  Chihuahua Shorthair/Dachshund
# 145602   Neutered Male        10 years             American Shorthair
#
#         color_intake
# 0       Yellow/White
# 1           Tricolor
# 2        Brown/White
# 3        Black/White
# 4         Black/Gray
# ...              ...
# 145598   Brown Tabby
# 145599   Brown Tabby
# 145600         Black
# 145601           Tan
# 145602   White/Black
#
# [145603 rows x 19 columns]

# %%
merged_df.columns
# Out:
# Index(['animal_id', 'name_outcome', 'outcome_type', 'animal_type_outcome',
#        'sex_upon_outcome', 'age_upon_outcome', 'breed_outcome',
#        'color_outcome', 'datetime_outcome', 'visit_count', 'datetime_intake',
#        'name_intake', 'intake_type', 'intake_condition', 'animal_type_intake',
#        'sex_upon_intake', 'age_upon_intake', 'breed_intake', 'color_intake'],
#       dtype='object')

# %%
# merged_df[['animal_id', 'name_outcome', 'name_intake']] # I have checked all names match - We can drop the name from the outcomes table

# %%
# merged_df[['animal_id', 'animal_type_outcome', 'animal_type_intake']] # I have checked all animal_types match - We can drop the outcome one

# %%
# merged_df[['animal_id', 'sex_upon_outcome', 'sex_upon_intake']]
# Compare sex_upon_outcome vs sex_upon_intake (treat NaN == NaN as True)
sex_equal = merged_df['sex_upon_outcome'].fillna("MISSING") == merged_df['sex_upon_intake'].fillna("MISSING")
# Check overall result
print("All equal?", sex_equal.all())
# Count mismatches
print("Number of mismatches:", (~sex_equal).sum())
# See mismatched rows
mismatches = merged_df.loc[~sex_equal, ['animal_id', 'sex_upon_outcome', 'sex_upon_intake']]
print(mismatches.head(10))

# They are changing since at the time of intake some ar intact and later they get spayed.
# For now we can keep both of these variables and then later we can drop the sex_upon_outcome since we can't really use it for prediction
# Out:
# All equal? False
# Number of mismatches: 63010
#     animal_id sex_upon_outcome sex_upon_intake
# 607   A501076    Spayed Female   Intact Female
# 609   A501255    Neutered Male     Intact Male
# 639   A504813    Spayed Female   Intact Female
# 672   A510475    Neutered Male     Intact Male
# 774   A524634    Spayed Female   Intact Female
# 821   A530122    Spayed Female   Intact Female
# 862   A533106    Neutered Male     Intact Male
# 898   A536136    Spayed Female   Intact Female
# 912   A538342    Spayed Female   Intact Female
# 967   A544105    Neutered Male     Intact Male

# %%
# merged_df['sex_upon_intake'].value_counts()

# %%
# merged_df[['animal_id', 'age_upon_intake', 'age_upon_outcome']]

# %%
cols_to_drop = ['name_outcome', 'animal_type_outcome', 'breed_outcome', 'color_outcome']
merged_df = merged_df.drop(columns=cols_to_drop)
print(merged_df.columns)
# Out:
# Index(['animal_id', 'outcome_type', 'sex_upon_outcome', 'age_upon_outcome',
#        'datetime_outcome', 'visit_count', 'datetime_intake', 'name_intake',
#        'intake_type', 'intake_condition', 'animal_type_intake',
#        'sex_upon_intake', 'age_upon_intake', 'breed_intake', 'color_intake'],
#       dtype='object')

# %%
merged_df = merged_df.rename(columns={
    'name_intake': 'name',
    'animal_type_intake': 'animal_type',
    'breed_intake': 'breed',
    'color_intake': 'color'
})
print(merged_df.columns)
# Out:
# Index(['animal_id', 'outcome_type', 'sex_upon_outcome', 'age_upon_outcome',
#        'datetime_outcome', 'visit_count', 'datetime_intake', 'name',
#        'intake_type', 'intake_condition', 'animal_type', 'sex_upon_intake',
#        'age_upon_intake', 'breed', 'color'],
#       dtype='object')

# %%
final_order = [
    'animal_id', 'name', 'sex_upon_outcome', 'sex_upon_intake',
    'age_upon_outcome', 'age_upon_intake',
    'datetime_outcome', 'datetime_intake',
    'visit_count', 'intake_type', 'intake_condition',
    'animal_type', 'breed', 'color', 'outcome_type'
]

merged_df = merged_df[final_order]

print(merged_df.columns)
# Out:
# Index(['animal_id', 'name', 'sex_upon_outcome', 'sex_upon_intake',
#        'age_upon_outcome', 'age_upon_intake', 'datetime_outcome',
#        'datetime_intake', 'visit_count', 'intake_type', 'intake_condition',
#        'animal_type', 'breed', 'color', 'outcome_type'],
#       dtype='object')

# %%
# Keep only rows where age_at_intake <= age_at_outcome
merged_df = merged_df[merged_df['age_upon_intake'] <= merged_df['age_upon_outcome']]

# Now drop the outcome-only columns
merged_df = merged_df.drop(
    ['age_upon_outcome', 'datetime_outcome', 'sex_upon_outcome'],
    axis=1
).reset_index(drop=True)

# %%
print(merged_df.columns)
print(merged_df.shape)
# Out:
# Index(['animal_id', 'name', 'sex_upon_intake', 'age_upon_intake',
#        'datetime_intake', 'visit_count', 'intake_type', 'intake_condition',
#        'animal_type', 'breed', 'color', 'outcome_type'],
#       dtype='object')
# (135235, 12)

# %%
# Save merged_df to CSV
merged_df.to_csv("merged_outcomes_intakes.csv", index=False)

# %% [markdown]
# # Ignore the script below

# %% [markdown]
# # Analysis:

# %%
import pandas as pd
merged_df = pd.read_csv('merged_outcomes_intakes.csv')

# %%
merged_df
# Out:
#        animal_id    name sex_upon_intake age_upon_intake      datetime_intake  \
# 0        A006100   Scamp   Neutered Male        10 years  2017-12-07 14:07:00
# 1        A047759    Oreo   Neutered Male        10 years  2014-04-02 15:55:00
# 2        A134067  Bandit   Neutered Male        16 years  2013-11-16 09:02:00
# 3        A141142  Bettie   Spayed Female        15 years  2013-11-16 14:46:00
# 4        A163459   Sasha   Intact Female        15 years  2014-11-14 15:11:00
# ...          ...     ...             ...             ...                  ...
# 135230   A929598     NaN         Unknown          4 days  2025-05-02 12:22:00
# 135231   A929599     NaN         Unknown          4 days  2025-05-02 12:22:00
# 135232   A929600     NaN         Unknown          4 days  2025-05-02 12:22:00
# 135233   A929602     NaN         Unknown          1 year  2025-05-02 12:22:00
# 135234   A929631   Fiona   Spayed Female        16 years  2025-05-02 20:27:00
#
#         visit_count      intake_type intake_condition animal_type  \
# 0                 3            Stray           Normal         Dog
# 1                 1  Owner Surrender           Normal         Dog
# 2                 1    Public Assist          Injured         Dog
# 3                 1            Stray             Aged         Dog
# 4                 1            Stray           Normal         Dog
# ...             ...              ...              ...         ...
# 135230            1            Stray         Neonatal         Cat
# 135231            1            Stray         Neonatal         Cat
# 135232            1            Stray         Neonatal         Cat
# 135233            1            Stray           Normal         Cat
# 135234            1            Stray          Injured         Dog
#
#                                 breed         color     outcome_type
# 0                Spinone Italiano Mix  Yellow/White  Return to Owner
# 1                           Dachshund      Tricolor         Transfer
# 2                   Shetland Sheepdog   Brown/White  Return to Owner
# 3         Labrador Retriever/Pit Bull   Black/White  Return to Owner
# 4             Miniature Schnauzer Mix    Black/Gray  Return to Owner
# ...                               ...           ...              ...
# 135230             Domestic Shorthair   Brown Tabby         Transfer
# 135231             Domestic Shorthair   Brown Tabby         Transfer
# 135232             Domestic Shorthair   Brown Tabby         Transfer
# 135233             Domestic Shorthair         Black         Transfer
# 135234  Chihuahua Shorthair/Dachshund           Tan       Euthanasia
#
# [135235 rows x 12 columns]

# %%
print(merged_df.isnull().sum())

# name - 38897 missing values - ~28.7%
# sex_upon_intake - 1 missing value
# outcome_type - 25 missing values
# Out:
# animal_id               0
# name                38897
# sex_upon_intake         1
# age_upon_intake         0
# datetime_intake         0
# visit_count             0
# intake_type             0
# intake_condition        0
# animal_type             0
# breed                   0
# color                   0
# outcome_type           25
# dtype: int64

# %%
merged_df.dropna(subset=["outcome_type"], inplace=True)

# %%
merged_df['breed'].nunique()
# Out:
# 2716

# %%
merged_df['color'].nunique()
# Out:
# 616

# %%
merged_df['outcome_type'].value_counts()
# Out:
# outcome_type
# Adoption           64328
# Transfer           44280
# Return to Owner    19631
# Euthanasia          4592
# Died                1178
# Rto-Adopt            897
# Disposal             239
# Missing               54
# Relocate               8
# Stolen                 2
# Lost                   1
# Name: count, dtype: int64

# %%
merged_df['sex_upon_intake'].value_counts()
# Out:
# sex_upon_intake
# Intact Male      46904
# Intact Female    46356
# Neutered Male    19620
# Spayed Female    16751
# Unknown           5603
# Name: count, dtype: int64

# %%
# Outcome Type Definitions (Austin Animal Center dataset)
#
# Adoption (64,328) 
#   - Animal was adopted into a new home from the shelter.
#
# Transfer (44,280) 
#   - Animal was moved to another organization (rescue, foster group, partner shelter).
#
# Return to Owner (19,631) 
#   - Lost pet was reunited with its original owner.
#
# Euthanasia (4,592) 
#   - Animal was humanely put down (severe illness, aggression, overcrowding).
#
# Died (1,178) 
#   - Animal died naturally while in shelter care (not euthanized).
#
# Disposal (239) 
#   - Animal found deceased and brought in for proper handling/disposal.
#
# Rto-Adopt (897) 
#   - Return-to-Owner followed immediately by adoption 
#     (e.g., owner surrendered rights and adopter took the animal).
#
# Missing (54) 
#   - Animal’s outcome is uncertain; shelter records show it went missing.
#
# Relocate (8) 
#   - Animal moved to a different facility/location (administrative, not a standard transfer).
#
# Stolen (2) 
#   - Animal reported stolen from shelter property or custody.
#
# Lost (1) 
#   - Animal lost while under shelter responsibility (rare case).
#
# Summary:
#   Positive outcomes → Adoption, Transfer, Return to Owner
#   Negative outcomes → Euthanasia, Died, Disposal, Missing, Stolen, Lost
#   Special/neutral outcomes → Rto-Adopt, Relocate

# %%
merged_df['intake_type'].value_counts()
# Out:
# intake_type
# Stray                 96590
# Owner Surrender       28930
# Public Assist          7904
# Abandoned              1575
# Euthanasia Request      235
# Wildlife                  1
# Name: count, dtype: int64

# %%
merged_df['intake_condition'].value_counts()
# Out:
# intake_condition
# Normal        115103
# Injured         8310
# Sick            5428
# Nursing         3067
# Neonatal        1584
# Medical          509
# Aged             478
# Other            290
# Pregnant         133
# Feral            122
# Med Attn          76
# Behavior          60
# Unknown           23
# Med Urgent        21
# Neurologic        11
# Parvo             11
# Space              4
# Agonal             3
# Panleuk            1
# Congenital         1
# Name: count, dtype: int64

# %% [markdown]
# # Feature engineering name column:

# %%
# # For analysis purpose:

# import pandas as pd

# # Get unique names, drop NaNs, sort them
# unique_names = sorted(merged_df['name'].dropna().unique())

# # Save to CSV
# pd.DataFrame(unique_names, columns=['Name']).to_csv("unique_names.csv", index=False)

# print(f"Saved {len(unique_names)} unique names to unique_names.csv")

# %%
# Has Name - 1, else 0

import pandas as pd
import re

def has_valid_name(name: str) -> int:
    """
    Return 1 if name looks like a valid given name, else 0.
    Implements the user-specified rules:
    - No digits, #, $, (, )
    - Length > 1
    - Not empty, NaN, or placeholders
    - Not generic group labels
    - Names starting with '*' are allowed
    """

    # Handle missing or NaN
    if pd.isna(name):
        return 0

    name_str = str(name).strip()
    if name_str == "" or name_str.isspace():
        return 0

    name_lower = name_str.lower()
        
    # if length <= 2 - return 0
    if len(name_lower) <= 2 :
        return 0
        
    # Preserve '*' names
    if name_str.startswith("*"):
        return 1

    # Rule 1: No numbers
    if any(char.isdigit() for char in name_lower):
        return 0

    # Rule 2: No # or $
    if "#" in name_lower or "$" in name_lower:
        return 0

    # Rule 3: No ( or )
    if "(" in name_lower or ")" in name_lower:
        return 0

    # Rule 4 & 5: invalid placeholders / generic labels
    invalid_terms = {
        "unknown", "unnamed", "no name", "nameless", "not named", "none",
        "stray", "animal", "dog", "puppy", "cat", "kitten",
        "male", "female", "litter", "deceased"
    }
    if name_lower in invalid_terms:
        return 0

    return 1

# Example usage:
# df["HasName"] = df["Name"].apply(has_valid_name)

# %%
# Applying this function to the name column:
merged_df["HasName"] = merged_df["name"].apply(has_valid_name)

# %%
# name_0 = merged_df[merged_df["HasName"] == 0]
# save = (name_0[['name','HasName']])
# save.to_csv("NoName.csv", index=False)

# %%
merged_df
# Out:
#        animal_id    name sex_upon_intake age_upon_intake      datetime_intake  \
# 0        A006100   Scamp   Neutered Male        10 years  2017-12-07 14:07:00
# 1        A047759    Oreo   Neutered Male        10 years  2014-04-02 15:55:00
# 2        A134067  Bandit   Neutered Male        16 years  2013-11-16 09:02:00
# 3        A141142  Bettie   Spayed Female        15 years  2013-11-16 14:46:00
# 4        A163459   Sasha   Intact Female        15 years  2014-11-14 15:11:00
# ...          ...     ...             ...             ...                  ...
# 135230   A929598     NaN         Unknown          4 days  2025-05-02 12:22:00
# 135231   A929599     NaN         Unknown          4 days  2025-05-02 12:22:00
# 135232   A929600     NaN         Unknown          4 days  2025-05-02 12:22:00
# 135233   A929602     NaN         Unknown          1 year  2025-05-02 12:22:00
# 135234   A929631   Fiona   Spayed Female        16 years  2025-05-02 20:27:00
#
#         visit_count      intake_type intake_condition animal_type  \
# 0                 3            Stray           Normal         Dog
# 1                 1  Owner Surrender           Normal         Dog
# 2                 1    Public Assist          Injured         Dog
# 3                 1            Stray             Aged         Dog
# 4                 1            Stray           Normal         Dog
# ...             ...              ...              ...         ...
# 135230            1            Stray         Neonatal         Cat
# 135231            1            Stray         Neonatal         Cat
# 135232            1            Stray         Neonatal         Cat
# 135233            1            Stray           Normal         Cat
# 135234            1            Stray          Injured         Dog
#
#                                 breed         color     outcome_type  HasName
# 0                Spinone Italiano Mix  Yellow/White  Return to Owner        1
# 1                           Dachshund      Tricolor         Transfer        1
# 2                   Shetland Sheepdog   Brown/White  Return to Owner        1
# 3         Labrador Retriever/Pit Bull   Black/White  Return to Owner        1
# 4             Miniature Schnauzer Mix    Black/Gray  Return to Owner        1
# ...                               ...           ...              ...      ...
# 135230             Domestic Shorthair   Brown Tabby         Transfer        0
# 135231             Domestic Shorthair   Brown Tabby         Transfer        0
# 135232             Domestic Shorthair   Brown Tabby         Transfer        0
# 135233             Domestic Shorthair         Black         Transfer        0
# 135234  Chihuahua Shorthair/Dachshund           Tan       Euthanasia        1
#
# [135235 rows x 13 columns]

# %%
# Creating a feature indicating the length of the name: (Only for HasName = 1)

# Create NameLength column
merged_df["NameLength"] = merged_df.apply(
    lambda row: len(str(row["name"]).strip()) if row["HasName"] == 1 else 0,
    axis=1
)

# Quick check
print(merged_df[["name", "HasName", "NameLength"]].head(20))

# Summary for valid names only
print(merged_df.loc[merged_df["HasName"] == 1, "NameLength"].describe())
# Out:
#           name  HasName  NameLength
# 0        Scamp        1           5
# 1         Oreo        1           4
# 2       Bandit        1           6
# 3       Bettie        1           6
# 4        Sasha        1           5
# 5          Pep        1           3
# 6         Boti        1           4
# 7      Ophelia        1           7
# 8      Bri-Bri        1           7
# 9   Sassafrass        1          10
# 10      Carlos        1           6
# 11     Kootrie        1           7
# 12       Caleb        1           5
# 13        Cujo        1           4
# 14      Prissy        1           6
# 15     Guiness        1           7
# 16      Oliver        1           6
# 17      Cookie        1           6
# 18       Lippy        1           5
# 19       Jamie        1           5
# count    91883.000000
# mean         6.092520
# std          2.026968
# min          3.000000
# 25%          5.000000
# 50%          6.000000
# 75%          7.000000
# max         30.000000
# Name: NameLength, dtype: float64

# %%
merged_df
# Out:
#        animal_id    name sex_upon_intake age_upon_intake      datetime_intake  \
# 0        A006100   Scamp   Neutered Male        10 years  2017-12-07 14:07:00
# 1        A047759    Oreo   Neutered Male        10 years  2014-04-02 15:55:00
# 2        A134067  Bandit   Neutered Male        16 years  2013-11-16 09:02:00
# 3        A141142  Bettie   Spayed Female        15 years  2013-11-16 14:46:00
# 4        A163459   Sasha   Intact Female        15 years  2014-11-14 15:11:00
# ...          ...     ...             ...             ...                  ...
# 135230   A929598     NaN         Unknown          4 days  2025-05-02 12:22:00
# 135231   A929599     NaN         Unknown          4 days  2025-05-02 12:22:00
# 135232   A929600     NaN         Unknown          4 days  2025-05-02 12:22:00
# 135233   A929602     NaN         Unknown          1 year  2025-05-02 12:22:00
# 135234   A929631   Fiona   Spayed Female        16 years  2025-05-02 20:27:00
#
#         visit_count      intake_type intake_condition animal_type  \
# 0                 3            Stray           Normal         Dog
# 1                 1  Owner Surrender           Normal         Dog
# 2                 1    Public Assist          Injured         Dog
# 3                 1            Stray             Aged         Dog
# 4                 1            Stray           Normal         Dog
# ...             ...              ...              ...         ...
# 135230            1            Stray         Neonatal         Cat
# 135231            1            Stray         Neonatal         Cat
# 135232            1            Stray         Neonatal         Cat
# 135233            1            Stray           Normal         Cat
# 135234            1            Stray          Injured         Dog
#
#                                 breed         color     outcome_type  HasName  \
# 0                Spinone Italiano Mix  Yellow/White  Return to Owner        1
# 1                           Dachshund      Tricolor         Transfer        1
# 2                   Shetland Sheepdog   Brown/White  Return to Owner        1
# 3         Labrador Retriever/Pit Bull   Black/White  Return to Owner        1
# 4             Miniature Schnauzer Mix    Black/Gray  Return to Owner        1
# ...                               ...           ...              ...      ...
# 135230             Domestic Shorthair   Brown Tabby         Transfer        0
# 135231             Domestic Shorthair   Brown Tabby         Transfer        0
# 135232             Domestic Shorthair   Brown Tabby         Transfer        0
# 135233             Domestic Shorthair         Black         Transfer        0
# 135234  Chihuahua Shorthair/Dachshund           Tan       Euthanasia        1
#
#         NameLength
# 0                5
# 1                4
# 2                6
# 3                6
# 4                5
# ...            ...
# 135230           0
# 135231           0
# 135232           0
# 135233           0
# 135234           5
#
# [135235 rows x 14 columns]

# %% [markdown]
# # Creating Features with age_upon_intake

# %%
merged_df['age_upon_intake'].value_counts()
# Out:
# age_upon_intake
# 2 years      21297
# 1 year       20592
# 1 month      16964
# 2 months      9523
# 3 years       7716
# 4 years       4741
# 3 months      4420
# 5 years       4331
# 4 months      4215
# 5 months      3457
# 3 weeks       3137
# 2 weeks       2899
# 6 years       2887
# 6 months      2653
# 7 years       2545
# 8 years       2439
# 10 years      2099
# 7 months      2059
# 4 weeks       1766
# 8 months      1545
# 1 week        1356
# 9 years       1310
# 1 weeks       1296
# 0 years       1120
# 10 months     1052
# 12 years      1030
# 1 day          956
# 11 years       815
# 9 months       729
# 13 years       654
# 2 days         628
# 3 days         621
# 14 years       493
# 15 years       429
# 11 months      374
# 4 days         270
# 6 days         238
# 16 years       182
# 5 days         151
# 17 years       101
# 18 years        56
# 5 weeks         28
# 19 years        27
# 20 years        22
# 22 years         6
# -1 years         2
# 23 years         1
# 24 years         1
# -4 years         1
# -3 years         1
# Name: count, dtype: int64

# %%
import pandas as pd
import re

def clean_and_parse_age_days(df, col="age_upon_intake"):
    """
    Clean anomalies, fix plural issues, and parse age_upon_intake into age_days.
    
    Steps:
    1. Drop anomalies with negative ages.
    2. Normalize plurals like '1 years' -> '1 year', '1 weeks' -> '1 week'.
    3. Convert all ages to days (integer).
    
    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe.
    col : str
        Column name containing age strings.
    
    Returns
    -------
    df : pd.DataFrame
        Dataframe with new column:
        - age_days
    """
    
    # Drop negative anomalies
    df = df[~df[col].astype(str).str.contains("-", na=False)].copy()
    
    # Fix plural issues for "1 unit"
    fixes = {
        r"\b1 years\b": "1 year",
        r"\b1 months\b": "1 month",
        r"\b1 weeks\b": "1 week",
        r"\b1 days\b": "1 day"
    }
    for wrong, right in fixes.items():
        df[col] = df[col].str.replace(wrong, right, regex=True)
    
    # Unit to days mapping
    unit_to_days = {"day": 1, "week": 7, "month": 30, "year": 365}
    
    def parse_age(age_str):
        if pd.isna(age_str) or str(age_str).strip() == "":
            return None
        match = re.match(r"(\d+)\s+(\w+)", str(age_str).lower())
        if not match:
            return None
        value, unit = int(match.group(1)), match.group(2).rstrip("s")
        return value * unit_to_days.get(unit, None)
    
    # Apply parser
    df["age_days"] = df[col].apply(parse_age)
    
    return df

# %%
merged_df = clean_and_parse_age_days(merged_df, col="age_upon_intake")

# quick check of results
print(merged_df.shape)
print(merged_df[["age_upon_intake", "age_days"]].sample(30))
# Out:
# (135231, 15)
#        age_upon_intake  age_days
# 57418           1 year       365
# 61126          4 years      1460
# 76888         10 years      3650
# 26126          1 month        30
# 123162          1 year       365
# 115078        8 months       240
# 77742          1 month        30
# 55326          1 month        30
# 1131          13 years      4745
# 52434          2 years       730
# 7930            1 year       365
# 44639          1 month        30
# 90571          2 years       730
# 671           15 years      5475
# 2488           8 years      2920
# 8507           1 month        30
# 58810           1 week         7
# 6620           5 years      1825
# 77289           1 year       365
# 105672         5 years      1825
# 97552           1 year       365
# 15057           1 year       365
# 100297          1 year       365
# 80762          3 weeks        21
# 18181           1 week         7
# 124657          1 year       365
# 39323          2 years       730
# 83750          5 years      1825
# 47136          1 month        30
# 85058         2 months        60

# %%
def add_age_group(df, col="age_days"):
    """
    Add a categorical 'age_group' column for dogs and cats based on biologically meaningful cutoffs.

    Groups:
    - Neonate: < 8 weeks (0–55 days)
    - Juvenile: 8 weeks – < 1 year (56–364 days)
    - Young Adult: 1 – < 7 years (365–2554 days)
    - Senior: 7+ years (2555+ days)

    Parameters
    ----------
    df : pd.DataFrame
        Input dataframe containing a numeric 'age_days' column.
    col : str
        Column name with numeric age in days.

    Returns
    -------
    df : pd.DataFrame
        Same dataframe with an additional column 'age_group'.
    """

    # Define cutoffs in **days** using right=False (left-inclusive bins):
    # 0–55 days    → Neonate
    # 56–364 days  → Juvenile
    # 365–2554 days → Young Adult
    # 2555+ days   → Senior
    bins = [0, 56, 365, 2555, float("inf")]

    # Labels that will be assigned to each bin
    labels = ["Neonate", "Juvenile", "Young Adult", "Senior"]

    # Use pd.cut to assign bins
    # right=False → intervals are [a, b), i.e. left-closed, right-open
    df["age_group"] = pd.cut(df[col], bins=bins, labels=labels, right=False)

    return df

# %%
merged_df = add_age_group(merged_df, col="age_days")
merged_df[['age_days', 'age_group']].sample(30)
# Out:
#         age_days    age_group
# 79572         30      Neonate
# 25523       1825  Young Adult
# 45602       1095  Young Adult
# 84114        120     Juvenile
# 86432         21      Neonate
# 92977        210     Juvenile
# 79123        730  Young Adult
# 96374        730  Young Adult
# 129114      1095  Young Adult
# 100301        30      Neonate
# 133137        60     Juvenile
# 15698        365  Young Adult
# 75053        730  Young Adult
# 35089       3285       Senior
# 96490        150     Juvenile
# 108488       730  Young Adult
# 12169         30      Neonate
# 128469        21      Neonate
# 113381       210     Juvenile
# 7128        1460  Young Adult
# 43829         21      Neonate
# 50924        365  Young Adult
# 77268        730  Young Adult
# 17617          7      Neonate
# 61755        365  Young Adult
# 38900        730  Young Adult
# 62180        730  Young Adult
# 120986       120     Juvenile
# 9160         365  Young Adult
# 107738         7      Neonate

# %% [markdown]
# # Creating features for sex_upon_intake:

# %%
merged_df['sex_upon_intake'].value_counts()
# Out:
# sex_upon_intake
# Intact Male      46903
# Intact Female    46355
# Neutered Male    19619
# Spayed Female    16750
# Unknown           5603
# Name: count, dtype: int64

# %%
merged_df['sex_upon_intake'] = merged_df['sex_upon_intake'].fillna("Unknown") # NaN - Unknown

# %%
# Define mapping dictionaries
intactness_mapping = {
    'Intact Male': 'intact',
    'Intact Female': 'intact',
    'Neutered Male': 'not_intact',
    'Spayed Female': 'not_intact',
    'Unknown': 'unknown'
}

sex_mapping = {
    'Intact Male': 'male',
    'Intact Female': 'female',
    'Neutered Male': 'male',
    'Spayed Female': 'female',
    'Unknown': 'unknown'
}

# Apply mappings
merged_df['intactness'] = merged_df['sex_upon_intake'].map(intactness_mapping)
merged_df['sex'] = merged_df['sex_upon_intake'].map(sex_mapping)

# %%
merged_df[['sex_upon_intake','sex','intactness']].sample(30)
# Out:
#        sex_upon_intake      sex  intactness
# 81814    Neutered Male     male  not_intact
# 59852          Unknown  unknown     unknown
# 124883     Intact Male     male      intact
# 51539    Intact Female   female      intact
# 101399   Intact Female   female      intact
# 66165    Intact Female   female      intact
# 103445   Neutered Male     male  not_intact
# 14564      Intact Male     male      intact
# 84891          Unknown  unknown     unknown
# 19615      Intact Male     male      intact
# 54701      Intact Male     male      intact
# 55352    Neutered Male     male  not_intact
# 76634      Intact Male     male      intact
# 85026    Spayed Female   female  not_intact
# 90578    Intact Female   female      intact
# 25222          Unknown  unknown     unknown
# 73772      Intact Male     male      intact
# 9544     Spayed Female   female  not_intact
# 58248    Spayed Female   female  not_intact
# 101946     Intact Male     male      intact
# 14051    Neutered Male     male  not_intact
# 83739    Intact Female   female      intact
# 114032     Intact Male     male      intact
# 105416   Intact Female   female      intact
# 102737     Intact Male     male      intact
# 97567      Intact Male     male      intact
# 36569    Neutered Male     male  not_intact
# 39548    Intact Female   female      intact
# 102765   Spayed Female   female  not_intact
# 46516    Neutered Male     male  not_intact

# %%
merged_df.columns
# Out:
# Index(['animal_id', 'name', 'sex_upon_intake', 'age_upon_intake',
#        'datetime_intake', 'visit_count', 'intake_type', 'intake_condition',
#        'animal_type', 'breed', 'color', 'outcome_type', 'HasName',
#        'NameLength', 'age_days', 'age_group', 'intactness', 'sex'],
#       dtype='object')

# %% [markdown]
# # Creating features for datetime_intake:

# %%
merged_df['datetime_intake']
# Out:
# 0         2017-12-07 14:07:00
# 1         2014-04-02 15:55:00
# 2         2013-11-16 09:02:00
# 3         2013-11-16 14:46:00
# 4         2014-11-14 15:11:00
#                  ...
# 135230    2025-05-02 12:22:00
# 135231    2025-05-02 12:22:00
# 135232    2025-05-02 12:22:00
# 135233    2025-05-02 12:22:00
# 135234    2025-05-02 20:27:00
# Name: datetime_intake, Length: 135231, dtype: object

# %%
merged_df['visit_count'].value_counts()
# Out:
# visit_count
# 1     122059
# 2      10478
# 3       1935
# 4        505
# 5        141
# 6         52
# 7         37
# 8         14
# 9          5
# 11         1
# 14         1
# 12         1
# 33         1
# 10         1
# Name: count, dtype: int64

# %%
# Ye niche ka thoda galat hai - Mid_Term vale script mai hai correct vaaala

# %%
import pandas as pd

merged_df['datetime_intake'] = pd.to_datetime(merged_df['datetime_intake'])

# Year
merged_df['intake_year'] = merged_df['datetime_intake'].dt.year

# Month
merged_df['intake_month'] = merged_df['datetime_intake'].dt.month_name()

# Day of Month
merged_df['intake_day'] = merged_df['datetime_intake'].dt.day

# Day of Week (full name)
merged_df['intake_weekday'] = merged_df['datetime_intake'].dt.day_name()

# Week Number of Year
merged_df['intake_week'] = merged_df['datetime_intake'].dt.isocalendar().week

# Hour of the Day
merged_df['intake_hour'] = merged_df['datetime_intake'].dt.hour

# Quarter of the Year
merged_df['intake_quarter'] = merged_df['datetime_intake'].dt.quarter

# Weekend flag with string weekdays
merged_df['is_weekend'] = merged_df['intake_weekday'].apply(
    lambda x: "Weekend" if x in ["Saturday", "Sunday"] else "Weekday"
)

# Season (Winter, Spring, Summer, Fall)
def get_season(month):
    if month in [12, 1, 2]:
        return "Winter"
    elif month in [3, 4, 5]:
        return "Spring"
    elif month in [6, 7, 8]:
        return "Summer"
    else:
        return "Fall"
merged_df['intake_season'] = merged_df['intake_month'].apply(get_season)

# AM/PM
merged_df['intake_am_pm'] = merged_df['intake_hour'].apply(lambda x: "AM" if x < 12 else "PM")

# Part of the Day
def part_of_day(hour):
    if 5 <= hour < 12:
        return "Morning"
    elif 12 <= hour < 17:
        return "Afternoon"
    elif 17 <= hour < 21:
        return "Evening"
    else:
        return "Night"
merged_df['intake_part_of_day'] = merged_df['intake_hour'].apply(part_of_day)

# %%
# Quick check of new features
merged_df[[
    "datetime_intake","intake_year","intake_month","intake_day","intake_weekday",
    "intake_week","intake_hour","intake_quarter","is_weekend","intake_season",
    "intake_am_pm","intake_part_of_day"
]].sample(30)
# Out:
#            datetime_intake  intake_year intake_month  intake_day  \
# 84903  2019-09-09 13:25:00         2019    September           9
# 112198 2022-08-26 18:13:00         2022       August          26
# 116754 2023-03-28 18:12:00         2023        March          28
# 70700  2018-09-11 13:58:00         2018    September          11
# 80297  2019-06-04 15:32:00         2019         June           4
# 31337  2015-08-27 12:37:00         2015       August          27
# 78480  2019-04-30 10:55:00         2019        April          30
# 52360  2017-04-18 10:48:00         2017        April          18
# 104005 2021-11-01 12:29:00         2021     November           1
# 74227  2018-12-22 18:25:00         2018     December          22
# 9831   2014-03-19 22:40:00         2014        March          19
# 105534 2022-01-02 10:40:00         2022      January           2
# 54230  2017-05-31 16:01:00         2017          May          31
# 2891   2015-07-15 15:09:00         2015         July          15
# 82160  2019-07-10 15:57:00         2019         July          10
# 84334  2019-08-27 08:58:00         2019       August          27
# 87570  2020-03-08 14:38:00         2020        March           8
# 21191  2014-12-14 16:29:00         2014     December          14
# 1787   2016-04-16 16:30:00         2016        April          16
# 122747 2023-11-08 07:04:00         2023     November           8
# 13477  2014-06-14 12:04:00         2014         June          14
# 22352  2015-01-21 15:24:00         2015      January          21
# 76444  2019-03-07 09:28:00         2019        March           7
# 102291 2021-09-08 11:19:00         2021    September           8
# 88179  2019-11-23 12:36:00         2019     November          23
# 50048  2017-01-30 14:04:00         2017      January          30
# 77987  2019-04-17 19:42:00         2019        April          17
# 19205  2014-10-19 17:13:00         2014      October          19
# 119050 2023-06-09 16:22:00         2023         June           9
# 9480   2014-03-09 18:10:00         2014        March           9
#
#        intake_weekday  intake_week  intake_hour  intake_quarter is_weekend  \
# 84903          Monday           37           13               3    Weekday
# 112198         Friday           34           18               3    Weekday
# 116754        Tuesday           13           18               1    Weekday
# 70700         Tuesday           37           13               3    Weekday
# 80297         Tuesday           23           15               2    Weekday
# 31337        Thursday           35           12               3    Weekday
# 78480         Tuesday           18           10               2    Weekday
# 52360         Tuesday           16           10               2    Weekday
# 104005         Monday           44           12               4    Weekday
# 74227        Saturday           51           18               4    Weekend
# 9831        Wednesday           12           22               1    Weekday
# 105534         Sunday           52           10               1    Weekend
# 54230       Wednesday           22           16               2    Weekday
# 2891        Wednesday           29           15               3    Weekday
# 82160       Wednesday           28           15               3    Weekday
# 84334         Tuesday           35            8               3    Weekday
# 87570          Sunday           10           14               1    Weekend
# 21191          Sunday           50           16               4    Weekend
# 1787         Saturday           15           16               2    Weekend
# 122747      Wednesday           45            7               4    Weekday
# 13477        Saturday           24           12               2    Weekend
# 22352       Wednesday            4           15               1    Weekday
# 76444        Thursday           10            9               1    Weekday
# 102291      Wednesday           36           11               3    Weekday
# 88179        Saturday           47           12               4    Weekend
# 50048          Monday            5           14               1    Weekday
# 77987       Wednesday           16           19               2    Weekday
# 19205          Sunday           42           17               4    Weekend
# 119050         Friday           23           16               2    Weekday
# 9480           Sunday           10           18               1    Weekend
#
#        intake_season intake_am_pm intake_part_of_day
# 84903           Fall           PM          Afternoon
# 112198          Fall           PM            Evening
# 116754          Fall           PM            Evening
# 70700           Fall           PM          Afternoon
# 80297           Fall           PM          Afternoon
# 31337           Fall           PM          Afternoon
# 78480           Fall           AM            Morning
# 52360           Fall           AM            Morning
# 104005          Fall           PM          Afternoon
# 74227           Fall           PM            Evening
# 9831            Fall           PM              Night
# 105534          Fall           AM            Morning
# 54230           Fall           PM          Afternoon
# 2891            Fall           PM          Afternoon
# 82160           Fall           PM          Afternoon
# 84334           Fall           AM            Morning
# 87570           Fall           PM          Afternoon
# 21191           Fall           PM          Afternoon
# 1787            Fall           PM          Afternoon
# 122747          Fall           AM            Morning
# 13477           Fall           PM          Afternoon
# 22352           Fall           PM          Afternoon
# 76444           Fall           AM            Morning
# 102291          Fall           AM            Morning
# 88179           Fall           PM          Afternoon
# 50048           Fall           PM          Afternoon
# 77987           Fall           PM            Evening
# 19205           Fall           PM            Evening
# 119050          Fall           PM          Afternoon
# 9480            Fall           PM            Evening

# %%
print(merged_df.shape)
# Out:
# (135231, 29)

# %%
merged_df.columns
# Out:
# Index(['animal_id', 'name', 'sex_upon_intake', 'age_upon_intake',
#        'datetime_intake', 'visit_count', 'intake_type', 'intake_condition',
#        'animal_type', 'breed', 'color', 'outcome_type', 'HasName',
#        'NameLength', 'age_days', 'age_group', 'intactness', 'sex',
#        'intake_year', 'intake_month', 'intake_day', 'intake_weekday',
#        'intake_week', 'intake_hour', 'intake_quarter', 'is_weekend',
#        'intake_season', 'intake_am_pm', 'intake_part_of_day'],
#       dtype='object')

# %% [markdown]
# # Creating features for visit_count:

# %%
# Create binary feature: 0 for first-time, 1 for return visitors
merged_df['is_return_visitor'] = (merged_df['visit_count'] > 1).astype(int)

# %%
merged_df[['is_return_visitor', 'visit_count']].sample(20)
# Out:
#         is_return_visitor  visit_count
# 2480                    1            2
# 37471                   0            1
# 17541                   1            2
# 42475                   0            1
# 11259                   0            1
# 21825                   0            1
# 88668                   0            1
# 39865                   0            1
# 7944                    0            1
# 28897                   0            1
# 49390                   0            1
# 127572                  0            1
# 19241                   0            1
# 60424                   0            1
# 122856                  0            1
# 113454                  0            1
# 33316                   0            1
# 12577                   0            1
# 21159                   0            1
# 117264                  0            1

# %%
merged_df.columns
# Out:
# Index(['animal_id', 'name', 'sex_upon_intake', 'age_upon_intake',
#        'datetime_intake', 'visit_count', 'intake_type', 'intake_condition',
#        'animal_type', 'breed', 'color', 'outcome_type', 'HasName',
#        'NameLength', 'age_days', 'age_group', 'intactness', 'sex',
#        'intake_year', 'intake_month', 'intake_day', 'intake_weekday',
#        'intake_week', 'intake_hour', 'intake_quarter', 'is_weekend',
#        'intake_season', 'intake_am_pm', 'intake_part_of_day',
#        'is_return_visitor'],
#       dtype='object')

# %% [markdown]
# # Features for intake_type:

# %%
merged_df['intake_type'].value_counts()
# Out:
# intake_type
# Stray                 96589
# Owner Surrender       28928
# Public Assist          7903
# Abandoned              1575
# Euthanasia Request      235
# Wildlife                  1
# Name: count, dtype: int64

# %%
merged_df.shape
# Out:
# (135231, 30)

# %%
# Drop rows where intake_type == "Wildlife"
merged_df = merged_df[merged_df['intake_type'] != "Wildlife"]
print(merged_df['intake_type'].value_counts())
merged_df.shape
# Out:
# intake_type
# Stray                 96589
# Owner Surrender       28928
# Public Assist          7903
# Abandoned              1575
# Euthanasia Request      235
# Name: count, dtype: int64
# (135230, 30)

# %%
# VOLUNTARY vs INVOLUNTARY INTAKE:
# - VOLUNTARY: Deliberate owner choices (Owner Surrender, Euthanasia Request)
#   - Owner makes active decision to bring animal to shelter
#   - May indicate behavioral issues, financial constraints, or life changes
# - INVOLUNTARY: Circumstantial situations (Stray, Abandoned, Public Assist)  
#   - Animal ends up at shelter due to circumstances, not owner decision
#   - More about animal control, public safety, or emergency situations

def voluntary_group(val):
    if val in ["Owner Surrender", "Euthanasia Request"]:
        return "Voluntary"
    elif val in ["Stray", "Abandoned", "Public Assist"]:
        return "Involuntary"
    else:
        return "Other"
merged_df['intake_voluntary'] = merged_df['intake_type'].apply(voluntary_group)

# %%
# HUMAN vs NON-HUMAN INITIATED:
# - HUMAN-INITIATED: Direct human action (Owner Surrender, Public Assist, Euthanasia Request)
#   - Specific person directly responsible for animal coming to shelter
#   - Often comes with more background information and known history
# - NON-HUMAN: System/environment driven (Stray, Abandoned)
#   - Animal comes through systematic channels rather than person's direct action
#   - Often unknown history, behavior, and more "mystery" about the animal

def human_group(val):
    if val in ["Owner Surrender", "Public Assist", "Euthanasia Request"]:
        return "Human"
    elif val in ["Stray", "Abandoned"]:
        return "Non-Human"
    else:
        return "Other"
merged_df['intake_human'] = merged_df['intake_type'].apply(human_group)

# %%
merged_df[['intake_type','intake_voluntary','intake_human']].sample(10)
# Out:
#           intake_type intake_voluntary intake_human
# 118644          Stray      Involuntary    Non-Human
# 58930           Stray      Involuntary    Non-Human
# 106244  Public Assist      Involuntary        Human
# 96898           Stray      Involuntary    Non-Human
# 88320           Stray      Involuntary    Non-Human
# 73203           Stray      Involuntary    Non-Human
# 27415           Stray      Involuntary    Non-Human
# 133714          Stray      Involuntary    Non-Human
# 109851          Stray      Involuntary    Non-Human
# 119000          Stray      Involuntary    Non-Human

# %% [markdown]
# # Features for intake_condition:

# %%
merged_df['intake_condition'].value_counts()
# Out:
# intake_condition
# Normal        115100
# Injured         8309
# Sick            5427
# Nursing         3067
# Neonatal        1584
# Medical          509
# Aged             478
# Other            290
# Pregnant         133
# Feral            122
# Med Attn          76
# Behavior          60
# Unknown           23
# Med Urgent        21
# Neurologic        11
# Parvo             11
# Space              4
# Agonal             3
# Panleuk            1
# Congenital         1
# Name: count, dtype: int64

# %%
def condition_group(val):
    if val in ["Normal"]:
        return "healthy"
    elif val in ["Injured", "Sick", "Medical", "Med Attn"]:
        return "medical_attention_needed"
    elif val in ["Med Urgent", "Neurologic", "Parvo", "Panleuk", "Congenital", "Agonal"]:
        return "critical_condition"
    elif val in ["Nursing", "Neonatal", "Pregnant", "Aged"]:
        return "special_care"
    elif val in ["Feral", "Behavior"]:
        return "behavioral"
    elif val in ["Unknown", "Other", "Space"]:
        return "Unknown"
    else:
        return "Other"

merged_df['intake_condition_grouped'] = merged_df['intake_condition'].apply(condition_group)

# %%
merged_df['intake_condition_grouped'].value_counts()
# Out:
# intake_condition_grouped
# healthy                     115100
# medical_attention_needed     14321
# special_care                  5262
# Unknown                        317
# behavioral                     182
# critical_condition              48
# Name: count, dtype: int64

# %%
merged_df['is_healthy'] = (merged_df['intake_condition_grouped'] == "healthy").astype(int)
print(merged_df[['intake_condition_grouped','is_healthy']])
# Out:
#         intake_condition_grouped  is_healthy
# 0                        healthy           1
# 1                        healthy           1
# 2       medical_attention_needed           0
# 3                   special_care           0
# 4                        healthy           1
# ...                          ...         ...
# 135230              special_care           0
# 135231              special_care           0
# 135232              special_care           0
# 135233                   healthy           1
# 135234  medical_attention_needed           0
#
# [135230 rows x 2 columns]

# %%
print(merged_df.columns)
print(merged_df.shape)
# Out:
# Index(['animal_id', 'name', 'sex_upon_intake', 'age_upon_intake',
#        'datetime_intake', 'visit_count', 'intake_type', 'intake_condition',
#        'animal_type', 'breed', 'color', 'outcome_type', 'HasName',
#        'NameLength', 'age_days', 'age_group', 'intactness', 'sex',
#        'intake_year', 'intake_month', 'intake_day', 'intake_weekday',
#        'intake_week', 'intake_hour', 'intake_quarter', 'is_weekend',
#        'intake_season', 'intake_am_pm', 'intake_part_of_day',
#        'is_return_visitor', 'intake_voluntary', 'intake_human',
#        'intake_condition_grouped', 'is_healthy'],
#       dtype='object')
# (135230, 34)

# %% [markdown]
# # Features for color:

# Sable/Tan                         42
# Black/Blue Tick                   40
# Silver Tabby/White                40
# Tan/Silver                        39
# Tan/Tricolor                      38
# White/Gray Tabby                  37
# White/Calico                      36
# Gold/Tan                          35
# White/Red Tick                    34
# White/Yellow                      33
# Blue Tiger/White                  33
# White/Fawn                        33
# Black Brindle/Brown               33
# Buff/Tan                          32
# White/Black Brindle               32
# White/Liver                       32
# Blue Tick/Tan                     32
# Blue Merle/Black                  31
# Yellow Brindle                    31
# Gray/Brown                        31
# Cream/Brown                       30
# Gray Tabby/Black                  30
# Brown/Red                         30
# Brown/Cream                       29
# Blue Tick/White                   29
# Tortie/Black                      29
# Brown Brindle/Brown               28
# Liver/White                       28
# Buff/Black                        27
# Brown Tiger                       27
# Silver Lynx Point                 26
# White/Brown Merle                 25
# Agouti                            23
# Black/Silver                      23
# Brown Tiger/White                 23
# Tan/Buff                          23
# Black/Black Brindle               21
# Chocolate/Tricolor                21
# Tricolor/Tan                      21
# White/Red Merle                   20
# Blue Point/White                  20
# Red/Cream                         19
# Gray/Gray                         19
# Lilac Point/White                 18
# Chocolate Point/White             18
# Silver/White                      17
# Sable/Brown                       17
# Tan/Red                           17
# Black/Buff                        17
# Black/Blue Merle                  17
# Blue Merle/Brown                  16
# Brown/Brown Brindle               16
# White/Blue Tick                   16
# Gray/Cream                        15
# Black/Orange                      15
# Calico/Black                      15
# Blue Tick/Tricolor                15
# Blue/Brown                        15
# Blue/Tricolor                     15
# Apricot/White                     14
# White/Black Tabby                 14
# Tortie/Blue Cream                 14
# Calico/Brown Tabby                14
# Blue Tick/Brown                   13
# Silver/Black                      13
# Brown/Silver                      13
# Fawn/Brown                        13
# Brown Tabby/Orange                13
# Blue Smoke                        13
# Fawn/Tan                          12
# Tortie Point/White                12
# Chocolate/Brown                   12
# Blue Cream/White                  12
# Blue Tiger                        12
# Blue/Black                        12
# White/Silver                      11
# Blue/Gray                         11
# Tricolor/Blue Merle               11
# Tan/Blue                          11
# Brown Brindle/Tan                 11
# Blue Merle/Tricolor               10
# Brown/Buff                        10
# Brown Tabby/Gray                  10
# Brown Tabby/Brown                 10
# Black/Fawn                        10
# Cream/Red                          9
# Tan/Fawn                           9
# Flame Point/White                  9
# Sable/Cream                        9
# Calico/Orange                      9
# Brown Merle/Tan                    9
# Tricolor/Blue                      9
# Silver/Brown                       9
# Black/Chocolate                    9
# Blue Tick/Red Tick                 9
# Blue/Brown Brindle                 9
# Liver Tick                         8
# Blue/Blue                          8
# Blue Tabby/Cream                   8
# Brown Tabby/Cream                  8
# Black/Blue                         7
# Tricolor/Blue Tick                 7
# Calico Point/White                 7
# Gold/Black                         7
# White/Silver Tabby                 7
# Calico/Calico                      7
# Fawn/Blue                          7
# White/Gold                         6
# Buff/Gray                          6
# Red Merle/Black                    6
# Brown Tabby/Tortie                 6
# Liver/Tan                          6
# Buff/Cream                         6
# White/Yellow Brindle               6
# Orange Tiger                       6
# Chocolate/Cream                    6
# Brown Brindle/Brown Brindle        6
# Red/Tricolor                       6
# Brown/Chocolate                    6
# Tortie/Orange                      6
# White/Apricot                      6
# Gold/Cream                         6
# Black Brindle/Black                6
# White/Seal Point                   6
# Cream/Gray                         6
# Red/Gray                           6
# Orange Tabby/Brown                 6
# Brown/Fawn                         5
# Black Tiger                        5
# Tortie/Blue                        5
# Orange Tabby/Cream                 5
# Brown/Red Tick                     5
# Red Tick/Red                       5
# Blue Smoke/White                   5
# Gold/Brown                         5
# Torbie/Brown                       5
# Blue/Tortie                        5
# Red/Buff                           5
# Gray/Tortie                        5
# Yellow/Tan                         5
# Red/Red Tick                       5
# Brown Merle/Black                  5
# White/Lynx Point                   5
# Calico/Tricolor                    5
# Tricolor/Gray                      5
# Black/Black Smoke                  5
# Black Smoke/Black Tabby            5
# Blue/Cream                         5
# Torbie/Orange                      5
# Brown Tabby/Brown Tabby            5
# Black Brindle/Brown Brindle        4
# Blue Tabby/Black                   4
# Cream/Seal Point                   4
# Chocolate/Brown Brindle            4
# Cream/Orange                       4
# Gray/Blue                          4
# Gray/Silver                        4
# Red Tick/Tan                       4
# Blue Tick/Red                      4
# Chocolate/Black                    4
# Chocolate/Red                      4
# Yellow/Cream                       4
# Tan/Yellow                         4
# Black/Brown Tabby                  4
# Liver Tick/Brown                   4
# Gray Tabby/Brown                   4
# Black/Yellow Brindle               4
# Orange Tabby/Orange Tabby          4
# Black/Gray Tabby                   4
# Gray/Tricolor                      4
# White/Blue Cream                   4
# Brown Merle/Brown                  4
# Cream/Red Tick                     4
# Torbie/Brown Tabby                 4
# Gold/Gold                          4
# Lynx Point/Tortie Point            4
# Cream/Yellow                       4
# Red Tick/Brown                     4
# Brown/Red Merle                    3
# Black Brindle/Tan                  3
# Buff/Yellow                        3
# Buff/Brown                         3
# White/Liver Tick                   3
# Yellow/Orange                      3
# Torbie/Gray                        3
# Black Tabby/Brown                  3
# Fawn/Tricolor                      3
# Agouti/White                       3
# Brown Tabby/Orange Tabby           3
# Chocolate/Chocolate                3
# Silver/Gray                        3
# Fawn/Gray                          3
# Black/Tortie                       3
# Tricolor/Red Tick                  3
# Black/Black Tabby                  3
# Red/Yellow                         3
# Black/Yellow                       3
# Silver/Red                         3
# Red/Red                            3
# Torbie/Black                       3
# Blue Cream/Tortie                  3
# Calico/Brown                       3
# White/Flame Point                  3
# Black Tabby/Gray                   3
# Brown Brindle/Red Tick             3
# Torbie/Blue Cream                  3
# Brown Brindle/Gray                 3
# Tan/Brown Brindle                  3
# Blue Merle/Blue Merle              3
# Tan/Red Merle                      3
# Chocolate/Gray                     3
# White/Black Smoke                  3
# Gray/Gray Tabby                    3
# Red/Silver                         3
# Silver Lynx Point/White            3
# Brown Brindle/Blue Tick            3
# Blue Merle/Gray                    3
# Calico/Blue Cream                  3
# Liver/Liver Tick                   3
# Lynx Point/Cream                   3
# Brown Tabby/Calico                 3
# Silver/Chocolate                   3
# Blue Tabby/Blue Cream              3
# Black Tiger/White                  3
# Calico/Gray                        3
# Tan/Red Tick                       3
# Tricolor/Red                       3
# Black/Brown Merle                  3
# White/Pink                         3
# Golden Retriever                                             76
# Russian Blue Mix                                             76
# French Bulldog                                               74
# Boston Terrier                                               73
# Jack Russell Terrier/Chihuahua Shorthair                     72
# Bull Terrier Mix                                             72
# Plott Hound                                                  72
# Papillon Mix                                                 69
# Dutch Shepherd Mix                                           69
# Labrador Retriever/Boxer                                     69
# Bull Terrier                                                 68
# Basenji Mix                                                  68
# Bichon Frise Mix                                             67
# Bulldog Mix                                                  66
# Soft Coated Wheaten Terrier Mix                              66
# Labrador Retriever/Beagle                                    65
# Basset Hound                                                 64
# West Highland Mix                                            63
# Chow Chow                                                    62
# Labrador Retriever/Pointer                                   62
# Wire Hair Fox Terrier                                        62
# Chihuahua Shorthair/Jack Russell Terrier                     61
# Mastiff                                                      61
# German Shorthair Pointer Mix                                 61
# Treeing Walker Coonhound Mix                                 58
# Border Terrier                                               58
# Pug/Beagle                                                   58
# Dalmatian Mix                                                57
# Pointer/Labrador Retriever                                   57
# Weimaraner Mix                                               57
# Pbgv Mix                                                     57
# German Shepherd/Australian Cattle Dog                        56
# Australian Cattle Dog/German Shepherd                        56
# Australian Cattle Dog/Pit Bull                               55
# Shiba Inu Mix                                                55
# Akita Mix                                                    55
# Lhasa Apso                                                   54
# Pug/Chihuahua Shorthair                                      53
# Vizsla Mix                                                   52
# Toy Poodle                                                   52
# Catahoula/Labrador Retriever                                 52
# Pit Bull/Australian Cattle Dog                               52
# Labrador Retriever/Chow Chow                                 51
# Norwich Terrier Mix                                          51
# Beagle/Labrador Retriever                                    51
# Bruss Griffon Mix                                            51
# American Foxhound Mix                                        51
# American Shorthair                                           50
# Wire Hair Fox Terrier Mix                                    49
# Dachshund Longhair                                           48
# Chinese Sharpei                                              48
# Miniature Poodle/Maltese                                     48
# Australian Kelpie                                            47
# Rottweiler/Labrador Retriever                                47
# German Shepherd/Alaskan Husky                                45
# Shetland Sheepdog Mix                                        45
# Labrador Retriever/Catahoula                                 44
# Pekingese                                                    44
# Smooth Fox Terrier Mix                                       43
# Collie Rough Mix                                             43
# English Coonhound Mix                                        42
# Ragdoll Mix                                                  42
# Anatol Shepherd/Great Pyrenees                               42
# Labrador Retriever/Australian Shepherd                       41
# Beagle/Dachshund                                             41
# Parson Russell Terrier Mix                                   41
# Blue Lacy                                                    40
# Border Collie/German Shepherd                                40
# Russian Blue                                                 40
# Cairn Terrier/Chihuahua Shorthair                            40
# Snowshoe                                                     39
# Labrador Retriever/Golden Retriever                          39
# Standard Poodle Mix                                          39
# Pointer/Pit Bull                                             39
# Havanese Mix                                                 38
# Scottish Terrier Mix                                         38
# Labrador Retriever/Plott Hound                               37
# Yorkshire Terrier/Chihuahua Shorthair                        37
# Labrador Retriever/Siberian Husky                            36
# Queensland Heeler                                            36
# Himalayan Mix                                                36
# Maine Coon                                                   36
# Chihuahua Shorthair/Cardigan Welsh Corgi                     35
# Bloodhound Mix                                               35
# Anatol Shepherd/Labrador Retriever                           35
# Greyhound Mix                                                35
# Australian Shepherd/Labrador Retriever                       35
# Pit Bull/German Shepherd                                     34
# Norwich Terrier                                              11
# German Shepherd/Golden Retriever                             11
# American Bulldog/Labrador Retriever                          11
# Patterdale Terr Mix                                          11
# Bearded Collie Mix                                           11
# Cardigan Welsh Corgi/Australian Cattle Dog                   11
# Jack Russell Terrier/Rat Terrier                             11
# Papillon                                                     11
# German Wirehaired Pointer/Labrador Retriever                 11
# Irish Wolfhound/Labrador Retriever                           10
# Basset Hound/Pit Bull                                        10
# Beagle/Basset Hound                                          10
# Miniature Poodle/Yorkshire Terrier                           10
# Rat Terrier/Beagle                                           10
# Boykin Span Mix                                              10
# Tonkinese Mix                                                10
# Doberman Pinsch/German Shepherd                              10
# Chihuahua Shorthair/Labrador Retriever                       10
# Pit Bull/Plott Hound                                         10
# Rottweiler/Pit Bull                                          10
# Cardigan Welsh Corgi/Labrador Retriever                      10
# Labrador Retriever/Queensland Heeler                         10
# Dachshund Longhair/Chihuahua Shorthair                       10
# Wirehaired Pointing Griffon Mix                              10
# Pit Bull/Mastiff                                             10
# Collie Smooth/Labrador Retriever                             10
# Labrador Retriever/Mastiff                                   10
# Yorkshire Terrier/Cairn Terrier                              10
# Dutch Shepherd                                               10
# Border Collie/Pit Bull                                       10
# Manchester Terrier                                           10
# German Shepherd/Chinese Sharpei                              10
# Havanese                                                     10
# Chihuahua Shorthair/Dachshund Wirehair                        9
# Staffordshire/Labrador Retriever                              9
# Plott Hound/Doberman Pinsch                                   9
# Doberman Pinsch/Labrador Retriever                            9
# Border Collie/Catahoula                                       9
# Basset Hound/Beagle                                           9
# Labrador Retriever/Rhod Ridgeback                             9
# Dalmatian/Labrador Retriever                                  9
# Yorkshire Terrier/Norfolk Terrier                             9
# Doberman Pinsch/Pit Bull                                      9
# Dachshund/Miniature Pinscher                                  9
# Boxer/Catahoula                                               9
# Pit Bull/Siberian Husky                                       9
# American Curl Shorthair Mix                                   9
# Australian Cattle Dog/Australian Shepherd                     9
# Tibetan Spaniel                                               9
# Skye Terrier Mix                                              9
# Chihuahua Shorthair/Manchester Terrier                        9
# Redbone Hound/Labrador Retriever                              9
# English Shepherd Mix                                          9
# Bull Terrier Miniature Mix                                    9
# Chihuahua Longhair/Cairn Terrier                              9
# Affenpinscher Mix                                             9
# Blue Lacy/Pit Bull                                            9
# Chihuahua Shorthair/Miniature Poodle                          9
# Unknown                                                       9
# Dogo Argentino                                                9
# Labrador Retriever/Bearded Collie                             9
# Great Pyrenees/Catahoula                                      9
# Field Spaniel                                                 9
# Labrador Retriever/Redbone Hound                              9
# Boxer/Pointer                                                 9
# English Pointer                                               9
# Picardy Sheepdog Mix                                          9
# Pointer/Boxer                                                 9
# Basenji                                                       9
# Dachshund/Chihuahua Longhair                                  8
# Flat Coat Retriever                                           8
# Catahoula/German Shepherd                                     8
# Australian Cattle Dog/Staffordshire                           8
# Treeing Tennesse Brindle Mix                                  8
# Dachshund/Australian Cattle Dog                               8
# Bombay Mix                                                    8
# Nova Scotia Duck Tolling Retriever                            8
# Australian Shepherd/Chow Chow                                 8
# Miniature Poodle/Bichon Frise                                 8
